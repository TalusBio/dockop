# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tqdm
import ray
from rdkit import Chem
from rdkit.Chem import rdMolDescriptors
from scipy import sparse
import logging
from functools import lru_cache
from mol2vec.features import mol2alt_sentence, sentences2vec
from gensim.models.word2vec import Word2Vec

# %%
ray.init()
# Out:
# 2021-05-27 10:01:22,539	INFO services.py:1267 -- View the Ray dashboard at http://127.0.0.1:8265
# {'node_ip_address': '172.31.35.146',
#  'raylet_ip_address': '172.31.35.146',
#  'redis_address': '172.31.35.146:6379',
#  'object_store_address': '/tmp/ray/session_2021-05-27_10-01-21_621651_7371/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2021-05-27_10-01-21_621651_7371/sockets/raylet',
#  'webui_url': '127.0.0.1:8265',
#  'session_dir': '/tmp/ray/session_2021-05-27_10-01-21_621651_7371',
#  'metrics_export_port': 57843,
#  'node_id': 'f3b45bed8f794fbe9963d6c72fdbb842cb1568390c535ac8a372ed62'}

# %%
NUM_CHUNKS = 1

# %%
USE_EMBEDDINGS = False

# %%
RECEPTOR = "EnamineHTS"
DATA_DIR = "/mnt/efs/enamine"
INPUT_DATA = f"{DATA_DIR}/{RECEPTOR}_scores.csv"

MODEL_PATH = "/home/ubuntu/mol2vec/examples/models/model_300dim.pkl"
UNCOMMON = "UNK"

# %%
@lru_cache(maxsize=2)
def get_data():
    ligands_df = pd.read_csv(INPUT_DATA)
    
    return ligands_df

# %%
@lru_cache(maxsize=2)
def get_w2v_model():
    word2vec_model = Word2Vec.load(MODEL_PATH)
    word2vec_model.wv.init_sims()
    return word2vec_model

# %%
@ray.remote
def create_fingerprint(smiles, score, i):
    if i % 10000 == 0:
        logging.basicConfig(level=logging.INFO)
        logging.info(i)
        
    mol = Chem.MolFromSmiles(smiles)
    pars = { "radius": 2,
             "nBits": 8192,
             "invariants": [],
             "fromAtoms": [],
             "useChirality": False,
             "useBondTypes": True,
             "useFeatures": True,
    }
    fp = rdMolDescriptors.GetMorganFingerprintAsBitVect(mol, **pars)
    onbits = list(fp.GetOnBits())

    return onbits, float(score)

# %%
@ray.remote
def create_mol_sentence(smiles, score, r, i):
    if i % 10000 == 0:
        logging.basicConfig(level=logging.INFO)
        logging.info(i)
        
    mol = Chem.MolFromSmiles(smiles)
    # smiles = Chem.MolToSmiles(mol)
    
    if not mol:
        return
    
    alt_sentence = mol2alt_sentence(mol, radius=r)
    
    return alt_sentence, score

# %%
def get_fingerprints(ligands_df, fp_size=8192):
    future_values = [create_fingerprint.remote(smiles=smiles, score=score, i=i) for (i, (smiles, score)) in enumerate(zip(ligands_df["smiles"], ligands_df["score"]))]
    
    values = [v for v in ray.get(future_values) if v]
    all_bits, scores = zip(*values)
    
    row_idx = []
    col_idx = []
    for i, bits in enumerate(all_bits):
        # these bits all have the same row:
        row_idx += [i] * len(bits)
        #and the column indices of those bits:
        col_idx += bits
    
    # generate a sparse matrix out of the row,col indices:
    unfolded_size = 8192
    fingerprint_matrix = sparse.coo_matrix((np.ones(len(row_idx)).astype(bool), 
                                           (row_idx, col_idx)), 
                                           shape=(max(row_idx)+1, unfolded_size))
    
    # convert to csr matrix, it is better:
    fingerprint_matrix =  sparse.csr_matrix(fingerprint_matrix)

    return fingerprint_matrix, scores

# %%
def get_embeddings(ligands_df, model, radius=1):
    future_values = [create_mol_sentence.remote(smiles=smiles, score=score, r=radius, i=i) for (i, (smiles, score)) in enumerate(zip(ligands_df["smiles"], ligands_df["score"]))]
    
    values = [v for v in ray.get(future_values) if v]
    mol_sentences, scores = zip(*values)

#     vectors = sentences2vec(sentences=mol_sentences, model=model, unseen=UNCOMMON)

    return mol_sentences, scores

# %%
ligands_df = get_data()

# %%
word2vec_model = get_w2v_model()
# Out:
# <ipython-input-27-e38f7f62ec60>:4: DeprecationWarning: Call to deprecated `init_sims` (Use fill_norms() instead. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#   word2vec_model.wv.init_sims()

# %%
start = time.time()
for i, df_chunk in enumerate(np.array_split(ligands_df, NUM_CHUNKS)):
    if USE_EMBEDDINGS:
        print("Generating mol2vec embeddings...")
        embeddings, scores = get_embeddings(ligands_df=df_chunk, model=word2vec_model, radius=1)
        vectors = sentences2vec(sentences=embeddings, model=word2vec_model, unseen=UNCOMMON)
        np.save(f"{DATA_DIR}/{RECEPTOR}_embeddings_{i}.npy", vectors)
        np.save(f"{DATA_DIR}/{RECEPTOR}_embedding_scores_{i}.npy", np.array(scores))
    else:
        print("Generating Morgan Fingerprints...")
        fingerprint_matrix, scores = get_fingerprints(ligands_df=df_chunk)
        sparse.save_npz(f"{DATA_DIR}/{RECEPTOR}_fingerprints_{i}.npz", fingerprint_matrix)
        np.save(f"{DATA_DIR}/{RECEPTOR}_scores_{i}.npy", np.array(scores))
    print(f"Chunk {i} took: {(time.time() - start)/60} mins")
    
print(f"Dataset took: {(time.time() - start)/60} mins")
# Out:
# Generating Morgan Fingerprints...
# (pid=7876) INFO:root:0
# (pid=7932) INFO:root:10000
# (pid=7937) INFO:root:20000
# (pid=7892) INFO:root:30000
# (pid=7885) INFO:root:40000
# (pid=7922) INFO:root:50000
# (pid=7921) INFO:root:60000
# (pid=7889) INFO:root:70000
# (pid=7894) INFO:root:80000
# (pid=7923) INFO:root:90000
# (pid=7886) INFO:root:100000
# (pid=7884) INFO:root:110000
# (pid=7894) INFO:root:120000
# (pid=7929) INFO:root:130000
# (pid=7940) INFO:root:140000
# (pid=7891) INFO:root:150000
# (pid=7934) INFO:root:160000
# (pid=7886) INFO:root:170000
# (pid=7929) INFO:root:180000
# (pid=7875) INFO:root:190000
# (pid=7934) INFO:root:200000
# (pid=7893) INFO:root:210000
# (pid=7929) INFO:root:220000
# (pid=7925) INFO:root:230000
# (pid=7921) INFO:root:240000
# (pid=7891) INFO:root:250000
# (pid=7884) INFO:root:260000
# (pid=7924) INFO:root:270000
# (pid=7887) INFO:root:280000
# (pid=7920) INFO:root:290000
# (pid=7929) INFO:root:300000
# (pid=7880) INFO:root:310000
# (pid=7934) INFO:root:320000
# (pid=7883) INFO:root:330000
# (pid=7925) INFO:root:340000
# (pid=7884) INFO:root:350000
# (pid=7890) INFO:root:360000
# (pid=7876) INFO:root:370000
# (pid=7895) INFO:root:380000
# (pid=7897) INFO:root:390000
# (pid=7921) INFO:root:400000
# (pid=7893) INFO:root:410000
# (pid=7890) INFO:root:420000
# (pid=7877) INFO:root:430000
# (pid=7884) INFO:root:440000
# (pid=7929) INFO:root:450000
# (pid=7875) INFO:root:460000
# (pid=7880) INFO:root:470000
# (pid=7887) INFO:root:480000
# (pid=7883) INFO:root:490000
# (pid=7923) INFO:root:500000
# (pid=7883) INFO:root:510000
# (pid=7880) INFO:root:520000
# (pid=7884) INFO:root:530000
# (pid=7891) INFO:root:540000
# (pid=7934) INFO:root:550000
# (pid=7882) INFO:root:560000
# (pid=7936) INFO:root:570000
# (pid=7897) INFO:root:580000
# (pid=7890) INFO:root:590000
# (pid=7887) INFO:root:600000
# (pid=7893) INFO:root:610000
# (pid=7880) INFO:root:620000
# (pid=7934) INFO:root:630000
# (pid=7885) INFO:root:640000
# (pid=7924) INFO:root:650000
# (pid=7891) INFO:root:660000
# (pid=7879) INFO:root:670000
# (pid=7940) INFO:root:680000
# (pid=7920) INFO:root:690000
# (pid=7921) INFO:root:700000
# (pid=7891) INFO:root:710000
# (pid=7877) INFO:root:720000
# (pid=7926) INFO:root:730000
# (pid=7887) INFO:root:740000
# (pid=7892) INFO:root:750000
# (pid=7922) INFO:root:760000
# (pid=7936) INFO:root:770000
# (pid=7892) INFO:root:780000
# (pid=7897) INFO:root:790000
# (pid=7937) INFO:root:800000
# (pid=7888) INFO:root:810000
# (pid=7919) INFO:root:820000
# (pid=7929) INFO:root:830000
# (pid=7929) INFO:root:840000
# (pid=7890) INFO:root:850000
# (pid=7878) INFO:root:860000
# (pid=7922) INFO:root:870000
# (pid=7894) INFO:root:880000
# (pid=7929) INFO:root:890000
# (pid=7891) INFO:root:900000
# (pid=7893) INFO:root:910000
# (pid=7919) INFO:root:920000
# (pid=7889) INFO:root:930000
# (pid=7919) INFO:root:940000
# (pid=7932) INFO:root:950000
# (pid=7923) INFO:root:960000
# (pid=7886) INFO:root:970000
# (pid=7886) INFO:root:980000
# (pid=7934) INFO:root:990000
# (pid=7892) INFO:root:1000000
# (pid=7885) INFO:root:1010000
# (pid=7887) INFO:root:1020000
# (pid=7934) INFO:root:1030000
# (pid=7895) INFO:root:1040000
# (pid=7894) INFO:root:1050000
# (pid=7885) INFO:root:1060000
# (pid=7876) INFO:root:1070000
# (pid=7924) INFO:root:1080000
# (pid=7921) INFO:root:1090000
# (pid=7883) INFO:root:1100000
# (pid=7888) INFO:root:1110000
# (pid=7888) INFO:root:1120000
# (pid=7880) INFO:root:1130000
# (pid=7893) INFO:root:1140000
# (pid=7891) INFO:root:1150000
# (pid=7876) INFO:root:1160000
# (pid=7921) INFO:root:1170000
# (pid=7882) INFO:root:1180000
# (pid=7934) INFO:root:1190000
# (pid=7883) INFO:root:1200000
# (pid=7895) INFO:root:1210000
# (pid=7895) INFO:root:1220000
# (pid=7897) INFO:root:1230000
# (pid=7883) INFO:root:1240000
# (pid=7929) INFO:root:1250000
# (pid=7878) INFO:root:1260000
# (pid=7878) INFO:root:1270000
# (pid=7887) INFO:root:1280000
# (pid=7878) INFO:root:1290000
# (pid=7890) INFO:root:1300000
# (pid=7937) INFO:root:1310000
# (pid=7919) INFO:root:1320000
# (pid=7883) INFO:root:1330000
# (pid=7932) INFO:root:1340000
# (pid=7934) INFO:root:1350000
# (pid=7879) INFO:root:1360000
# (pid=7883) INFO:root:1370000
# (pid=7936) INFO:root:1380000
# (pid=7937) INFO:root:1390000
# (pid=7934) INFO:root:1400000
# (pid=7929) INFO:root:1410000
# (pid=7885) INFO:root:1420000
# (pid=7886) INFO:root:1430000
# (pid=7894) INFO:root:1440000
# (pid=7884) INFO:root:1450000
# (pid=7889) INFO:root:1460000
# (pid=7886) INFO:root:1470000
# (pid=7936) INFO:root:1480000
# (pid=7892) INFO:root:1490000
# (pid=7875) INFO:root:1500000
# (pid=7929) INFO:root:1510000
# (pid=7926) INFO:root:1520000
# (pid=7888) INFO:root:1530000
# (pid=7922) INFO:root:1540000
# (pid=7934) INFO:root:1550000
# (pid=7887) INFO:root:1560000
# (pid=7924) INFO:root:1570000
# (pid=7893) INFO:root:1580000
# (pid=7895) INFO:root:1590000
# (pid=7923) INFO:root:1600000
# (pid=7926) INFO:root:1610000
# (pid=7883) INFO:root:1620000
# (pid=7920) INFO:root:1630000
# (pid=7897) INFO:root:1640000
# (pid=7886) INFO:root:1650000
# (pid=7937) INFO:root:1660000
# (pid=7924) INFO:root:1670000
# (pid=7892) INFO:root:1680000
# (pid=7881) INFO:root:1690000
# (pid=7883) INFO:root:1700000
# (pid=7884) INFO:root:1710000
# (pid=7924) INFO:root:1720000
# (pid=7886) INFO:root:1730000
# (pid=7879) INFO:root:1740000
# (pid=7888) INFO:root:1750000
# (pid=7894) INFO:root:1760000
# (pid=7876) INFO:root:1770000
# (pid=7919) INFO:root:1780000
# (pid=7883) INFO:root:1790000
# (pid=7929) INFO:root:1800000
# (pid=7897) INFO:root:1810000
# (pid=7929) INFO:root:1820000
# (pid=7878) INFO:root:1830000
# (pid=7892) INFO:root:1840000
# (pid=7883) INFO:root:1850000
# (pid=7888) INFO:root:1860000
# (pid=7877) INFO:root:1870000
# (pid=7932) INFO:root:1880000
# (pid=7936) INFO:root:1890000
# (pid=7920) INFO:root:1900000
# (pid=7922) INFO:root:1910000
# (pid=7883) INFO:root:1920000
# (pid=7881) INFO:root:1930000
# (pid=7925) INFO:root:1940000
# (pid=7934) INFO:root:1950000
# (pid=7877) INFO:root:1960000
# (pid=7878) INFO:root:1970000
# (pid=7894) INFO:root:1980000
# (pid=7890) INFO:root:1990000
# (pid=7919) INFO:root:2000000
# (pid=7895) INFO:root:2010000
# (pid=7878) INFO:root:2020000
# (pid=7882) INFO:root:2030000
# (pid=7879) INFO:root:2040000
# (pid=7893) INFO:root:2050000
# (pid=7929) INFO:root:2060000
# (pid=7885) INFO:root:2070000
# (pid=7878) INFO:root:2080000
# (pid=7888) INFO:root:2090000
# (pid=7888) INFO:root:2100000
