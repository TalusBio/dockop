# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tqdm
import ray
from rdkit import Chem
from rdkit.Chem import rdMolDescriptors
from scipy import sparse
import logging

# %%
ray.init()
# Out:
# 2021-05-26 19:40:09,185	INFO services.py:1267 -- View the Ray dashboard at http://127.0.0.1:8265
# {'node_ip_address': '172.31.34.223',
#  'raylet_ip_address': '172.31.34.223',
#  'redis_address': '172.31.34.223:6379',
#  'object_store_address': '/tmp/ray/session_2021-05-26_19-40-08_300604_16307/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2021-05-26_19-40-08_300604_16307/sockets/raylet',
#  'webui_url': '127.0.0.1:8265',
#  'session_dir': '/tmp/ray/session_2021-05-26_19-40-08_300604_16307',
#  'metrics_export_port': 61120,
#  'node_id': 'e99384c38e3f2540aa3c7c0ecca53d3b6a104b0be5df1f2510a9a0d0'}

# %%
RECEPTOR = "EnamineHTS"
INPUT_DATA = f"/mnt/efs/enamine/EnamineHTS_scores.csv"
OUTPUT_DATA_DIR = "../processed_data"

# %%
def get_data():
    ligands_df = pd.read_csv(INPUT_DATA)
    
    return ligands_df

# %% [markdown]
# # Fingerprint molecules
# The whole set of fingerprints won't fit in memory (even sparse) so we have to save them as chunks. This iterates over the SMILES codes, generating fingerprint_matrices and score arrays, saving them as chunks of 10,000,000

# %%
@ray.remote
def create_fingerprint(smiles, score, i):
    if i % 10000 == 0:
        logging.basicConfig(level=logging.INFO)
        logging.info(i)
        
    mol = Chem.MolFromSmiles(smiles)
    pars = { "radius": 2,
             "nBits": 8192,
             "invariants": [],
             "fromAtoms": [],
             "useChirality": False,
             "useBondTypes": True,
             "useFeatures": True,
    }
    fp = rdMolDescriptors.GetMorganFingerprintAsBitVect(mol, **pars)
    onbits = list(fp.GetOnBits())

    return onbits, float(score)

# %%
def get_fingerprints(ligands_df, fp_size=8192):
    future_values = [create_fingerprint.remote(smiles=smiles, score=score, i=i) for (i, (smiles, score)) in enumerate(zip(ligands_df["smiles"], ligands_df["score"]))]
    
    values = [v for v in ray.get(future_values) if v]
    all_bits, scores = zip(*values)
    
    row_idx = []
    col_idx = []
    for i, bits in enumerate(all_bits):
        # these bits all have the same row:
        row_idx += [i] * len(bits)
        #and the column indices of those bits:
        col_idx += bits
    
    # generate a sparse matrix out of the row,col indices:
    unfolded_size = 8192
    fingerprint_matrix = sparse.coo_matrix((np.ones(len(row_idx)).astype(bool), 
                                           (row_idx, col_idx)), 
                                           shape=(max(row_idx)+1, unfolded_size))
    
    # convert to csr matrix, it is better:
    fingerprint_matrix =  sparse.csr_matrix(fingerprint_matrix)

    return fingerprint_matrix, scores

# %%
ligands_df = get_data()

# %%
fingerprint_matrix, scores = get_fingerprints(ligands_df=ligands_df)
# Out:
# (pid=16453) INFO:root:0
# (pid=16447) INFO:root:10000
# (pid=16446) INFO:root:20000
# (pid=16448) INFO:root:30000
# (pid=16454) INFO:root:40000
# (pid=16445) INFO:root:50000
# (pid=16451) INFO:root:60000
# (pid=16450) INFO:root:70000
# (pid=16452) INFO:root:80000
# (pid=16454) INFO:root:90000
# (pid=16449) INFO:root:100000
# (pid=16450) INFO:root:110000
# (pid=16452) INFO:root:120000
# (pid=16461) INFO:root:130000
# (pid=16444) INFO:root:140000
# (pid=16452) INFO:root:150000
# (pid=16444) INFO:root:160000
# (pid=16459) INFO:root:170000
# (pid=16452) INFO:root:180000
# (pid=16465) INFO:root:190000
# (pid=16449) INFO:root:200000
# (pid=16461) INFO:root:210000
# (pid=16444) INFO:root:220000
# (pid=16465) INFO:root:230000
# (pid=16460) INFO:root:240000
# (pid=16449) INFO:root:250000
# (pid=16448) INFO:root:260000
# (pid=16459) INFO:root:270000
# (pid=16444) INFO:root:280000
# (pid=16447) INFO:root:290000
# (pid=16453) INFO:root:300000
# (pid=16448) INFO:root:310000
# (pid=16443) INFO:root:320000
# (pid=16451) INFO:root:330000
# (pid=16453) INFO:root:340000
# (pid=16450) INFO:root:350000
# (pid=16450) INFO:root:360000
# (pid=16460) INFO:root:370000
# (pid=16453) INFO:root:380000
# (pid=16446) INFO:root:390000
# (pid=16450) INFO:root:400000
# (pid=16459) INFO:root:410000
# (pid=16448) INFO:root:420000
# (pid=16444) INFO:root:430000
# (pid=16453) INFO:root:440000
# (pid=16448) INFO:root:450000
# (pid=16465) INFO:root:460000
# (pid=16452) INFO:root:470000
# (pid=16454) INFO:root:480000
# (pid=16459) INFO:root:490000
# (pid=16445) INFO:root:500000
# (pid=16460) INFO:root:510000
# (pid=16444) INFO:root:520000
# (pid=16444) INFO:root:530000
# (pid=16450) INFO:root:540000
# (pid=16459) INFO:root:550000
# (pid=16461) INFO:root:560000
# (pid=16445) INFO:root:570000
# (pid=16453) INFO:root:580000
# (pid=16465) INFO:root:590000
# (pid=16448) INFO:root:600000
# (pid=16465) INFO:root:610000
# (pid=16445) INFO:root:620000
# (pid=16459) INFO:root:630000
# (pid=16451) INFO:root:640000
# (pid=16452) INFO:root:650000
# (pid=16453) INFO:root:660000
# (pid=16460) INFO:root:670000
# (pid=16452) INFO:root:680000
# (pid=16452) INFO:root:690000
# (pid=16450) INFO:root:700000
# (pid=16461) INFO:root:710000
# (pid=16461) INFO:root:720000
# (pid=16443) INFO:root:730000
# (pid=16460) INFO:root:740000
# (pid=16444) INFO:root:750000
# (pid=16449) INFO:root:760000
# (pid=16454) INFO:root:770000
# (pid=16460) INFO:root:780000
# (pid=16443) INFO:root:790000
# (pid=16451) INFO:root:800000
# (pid=16443) INFO:root:810000
# (pid=16450) INFO:root:820000
# (pid=16445) INFO:root:830000
# (pid=16444) INFO:root:840000
# (pid=16461) INFO:root:850000
# (pid=16446) INFO:root:860000
# (pid=16450) INFO:root:870000
# (pid=16453) INFO:root:880000
# (pid=16446) INFO:root:890000
# (pid=16459) INFO:root:900000
# (pid=16447) INFO:root:910000
# (pid=16454) INFO:root:920000
# (pid=16461) INFO:root:930000
# (pid=16451) INFO:root:940000
# (pid=16454) INFO:root:950000
# (pid=16453) INFO:root:960000
# (pid=16444) INFO:root:970000
# (pid=16449) INFO:root:980000
# (pid=16454) INFO:root:990000
# (pid=16448) INFO:root:1000000
# (pid=16443) INFO:root:1010000
# (pid=16451) INFO:root:1020000
# (pid=16448) INFO:root:1030000
# (pid=16448) INFO:root:1040000
# (pid=16454) INFO:root:1050000
# (pid=16451) INFO:root:1060000
# (pid=16452) INFO:root:1070000
# (pid=16460) INFO:root:1080000
# (pid=16447) INFO:root:1090000
# (pid=16452) INFO:root:1100000
# (pid=16465) INFO:root:1110000
# (pid=16445) INFO:root:1120000
# (pid=16449) INFO:root:1130000
# (pid=16446) INFO:root:1140000
# (pid=16448) INFO:root:1150000
# (pid=16448) INFO:root:1160000
# (pid=16447) INFO:root:1170000
# (pid=16444) INFO:root:1180000
# (pid=16446) INFO:root:1190000
# (pid=16453) INFO:root:1200000
# (pid=16465) INFO:root:1210000
# (pid=16459) INFO:root:1220000
# (pid=16446) INFO:root:1230000
# (pid=16448) INFO:root:1240000
# (pid=16454) INFO:root:1250000
# (pid=16444) INFO:root:1260000
# (pid=16446) INFO:root:1270000
# (pid=16444) INFO:root:1280000
# (pid=16445) INFO:root:1290000
# (pid=16447) INFO:root:1300000
# (pid=16445) INFO:root:1310000
# (pid=16465) INFO:root:1320000
# (pid=16461) INFO:root:1330000
# (pid=16453) INFO:root:1340000
# (pid=16459) INFO:root:1350000
# (pid=16448) INFO:root:1360000
# (pid=16452) INFO:root:1370000
# (pid=16447) INFO:root:1380000
# (pid=16454) INFO:root:1390000
# (pid=16459) INFO:root:1400000
# (pid=16452) INFO:root:1410000
# (pid=16445) INFO:root:1420000
# (pid=16449) INFO:root:1430000
# (pid=16461) INFO:root:1440000
# (pid=16451) INFO:root:1450000
# (pid=16444) INFO:root:1460000
# (pid=16459) INFO:root:1470000
# (pid=16459) INFO:root:1480000
# (pid=16444) INFO:root:1490000
# (pid=16452) INFO:root:1500000
# (pid=16446) INFO:root:1510000
# (pid=16446) INFO:root:1520000
# (pid=16444) INFO:root:1530000
# (pid=16451) INFO:root:1540000
# (pid=16459) INFO:root:1550000
# (pid=16452) INFO:root:1560000
# (pid=16461) INFO:root:1570000
# (pid=16465) INFO:root:1580000
# (pid=16465) INFO:root:1590000
# (pid=16459) INFO:root:1600000
# (pid=16445) INFO:root:1610000
# (pid=16459) INFO:root:1620000
# (pid=16454) INFO:root:1630000
# (pid=16449) INFO:root:1640000
# (pid=16460) INFO:root:1650000
# (pid=16449) INFO:root:1660000
# (pid=16454) INFO:root:1670000
# (pid=16450) INFO:root:1680000
# (pid=16448) INFO:root:1690000
# (pid=16446) INFO:root:1700000
# (pid=16459) INFO:root:1710000
# (pid=16452) INFO:root:1720000
# (pid=16454) INFO:root:1730000
# (pid=16461) INFO:root:1740000
# (pid=16453) INFO:root:1750000
# (pid=16447) INFO:root:1760000
# (pid=16454) INFO:root:1770000
# (pid=16450) INFO:root:1780000
# (pid=16465) INFO:root:1790000
# (pid=16459) INFO:root:1800000
# (pid=16449) INFO:root:1810000
# (pid=16461) INFO:root:1820000
# (pid=16460) INFO:root:1830000
# (pid=16451) INFO:root:1840000
# (pid=16444) INFO:root:1850000
# (pid=16453) INFO:root:1860000
# (pid=16447) INFO:root:1870000
# (pid=16454) INFO:root:1880000
# (pid=16454) INFO:root:1890000
# (pid=16444) INFO:root:1900000
# (pid=16449) INFO:root:1910000
# (pid=16461) INFO:root:1920000
# (pid=16459) INFO:root:1930000
# (pid=16446) INFO:root:1940000
# (pid=16452) INFO:root:1950000
# (pid=16446) INFO:root:1960000
# (pid=16446) INFO:root:1970000
# (pid=16461) INFO:root:1980000
# (pid=16453) INFO:root:1990000
# (pid=16446) INFO:root:2000000
# (pid=16451) INFO:root:2010000
# (pid=16449) INFO:root:2020000
# (pid=16450) INFO:root:2030000
# (pid=16465) INFO:root:2040000
# (pid=16461) INFO:root:2050000
# (pid=16443) INFO:root:2060000
# (pid=16449) INFO:root:2070000
# (pid=16465) INFO:root:2080000
# (pid=16453) INFO:root:2090000
# (pid=16459) INFO:root:2100000

# %%
sparse.save_npz(f"{OUTPUT_DATA_DIR}/{RECEPTOR}_fingerprints.npz", fingerprint_matrix)
np.save(f"{OUTPUT_DATA_DIR}/{RECEPTOR}_scores.npy", np.array(scores))
# Out:
# 2021-05-26 22:26:51,867	WARNING worker.py:1115 -- The autoscaler failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/dockop/lib/python3.8/site-packages/ray/_private/monitor.py", line 284, in run
#     self._run()
#   File "/home/ubuntu/anaconda3/envs/dockop/lib/python3.8/site-packages/ray/_private/monitor.py", line 175, in _run
#     self.update_load_metrics()
#   File "/home/ubuntu/anaconda3/envs/dockop/lib/python3.8/site-packages/ray/_private/monitor.py", line 139, in update_load_metrics
#     response = self.gcs_node_resources_stub.GetAllResourceUsage(
#   File "/home/ubuntu/anaconda3/envs/dockop/lib/python3.8/site-packages/grpc/_channel.py", line 946, in __call__
#     return _end_unary_response_blocking(state, call, False, None)
#   File "/home/ubuntu/anaconda3/envs/dockop/lib/python3.8/site-packages/grpc/_channel.py", line 849, in _end_unary_response_blocking
#     raise _InactiveRpcError(state)
# grpc._channel._InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.DEADLINE_EXCEEDED
# 	details = "Deadline Exceeded"
# 	debug_error_string = "{"created":"@1622067915.675856421","description":"Error received from peer ipv4:172.31.34.223:44337","file":"src/core/lib/surface/call.cc","file_line":1066,"grpc_message":"Deadline Exceeded","grpc_status":4}"
# >
